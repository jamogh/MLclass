# %% [markdown]
# <a href="https://colab.research.google.com/github/jamogh/MLclass/blob/main/ml_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

x=[1,3,5,7]
y=[2,4,6,1]
plt.plot(x,y)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title("A simple line graph")
plt.show()

# %%
import matplotlib.pyplot as plt

left_coordinates=[1,2,3,4,5]
heights=[10,20,30,15,40]
bar_labels=['One','Two','Three','Four','Five']
plt.bar(left_coordinates,heights,tick_label=bar_labels,width=0.6,color=['red','black'])
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title("A simple bar graph")
plt.show()

# %%
import matplotlib.pyplot as plt

x=[1,2,3,4,5]
y=[1,2,3,4,5]
plt.plot(x,y)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title("A star graph")
plt.show()

# %%
from google.colab import drive
drive.mount ('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd


df = pd.read_excel("/content/drive/MyDrive/indian_startup_funding_Lab1.xlsx")
print(df)
# Out:
#      Sr No       Date                                       Startup Name  \
# 0       17 2019-12-20                                       Lenskart.com
# 1       12 2019-12-17                                         Healthians
# 2       13 2019-12-16                                            Licious
# 3       14 2019-12-16                                             InCred
# 4       15 2019-12-14                                              Trell
# ..     ...        ...                                                ...
# 106    114 2019-02-08                                            Zilingo
# 107    113 2019-02-01                                             FleetX
# 108    118 2019-01-04                            Vyome Therapeutics Inc.
# 109    119 2019-01-04  Samunnati Financial Intermediation & Services ...
# 110    117 2019-01-03                                           CarDekho
#
#                 Industry Vertical                               SubVertical  \
# ...

# %%
df.isnull().sum()
# Out:
# Sr No                  0
# Date                   0
# Startup Name           0
# Industry Vertical      0
# SubVertical            0
# City  Location         0
# Investors Name         2
# InvestmentnType        3
# Amount in USD          0
# Remarks              111
# dtype: int64
